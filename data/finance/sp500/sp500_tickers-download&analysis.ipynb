# %% [markdown]
# Data downloaded:
# * https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks/data
# * https://stockanalysis.com/list/sp-500-stocks/

# %% [markdown]
# # Configuration

# %%
# !pip install python-dotenv

# %%
# !pip install kagglehub

# %%
import os
import shutil
import kagglehub
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly as py # data visualization
import plotly.graph_objs as go
from dotenv import load_dotenv
from plotly.offline import init_notebook_mode, iplot, plot # need this to plot figures
init_notebook_mode(connected=True)

# matplotlib
import matplotlib.pyplot as plt
os.environ["KAGGLE_CONFIG_DIR"] = "./"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
load_dotenv()

USERNAME = os.getenv("KAGGLE_USERNAME")
API_KEY = os.getenv("KEY")
PROJECT_PATH = os.getenv("KAGGLE_CONFIG_DIR") + "raw"

# %% [markdown]
# # Download and move data

# %%
# Download latest version
path = kagglehub.dataset_download("andrewmvd/sp-500-stocks")
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

print("Path to dataset files:", path[-20:])

for file in os.listdir(path):
    src = os.path.join(path, file)
    dest = os.path.join(PROJECT_PATH, file)

    if not os.path.exists(dest):
        shutil.move(src, dest)
        print(f"Moved: {file}")
    else:
        print(f"Skipped (already exists): {file}")

print(f"Path to dataset files moved to: {PROJECT_PATH}")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/andrewmvd/sp-500-stocks?dataset_version_number=1009...
# 100%|██████████| 44.4M/44.4M [00:10<00:00, 4.55MB/s]
# Extracting files...
# Path to dataset files: stocks\versions\1009
# Moved: sp500_companies.csv
# Moved: sp500_index.csv
# Moved: sp500_stocks.csv
# Path to dataset files moved to: ./raw

# %% [markdown]
# # Read data

# %%
data = {}

for file in os.listdir(PROJECT_PATH):
    if file.endswith(".csv"):
        file_path = os.path.join(PROJECT_PATH, file)
        key = os.path.splitext(file)[0]
        data[key] = pd.read_csv(file_path)

print("Loaded datasets:", list(data.keys()))
# Out:
# Loaded datasets: ['sp500_companies', 'sp500_index', 'sp500_stocks']

# %%
for key in data.keys():
    print(key)
    display(data[key])
# Out:
# sp500_companies
#     Exchange Symbol                        Shortname  \
# 0        NMS   AAPL                       Apple Inc.
# 1        NMS   NVDA               NVIDIA Corporation
# 2        NMS   MSFT            Microsoft Corporation
# 3        NMS   AMZN                 Amazon.com, Inc.
# 4        NMS   GOOG                    Alphabet Inc.
# ..       ...    ...                              ...
# 498      NYQ    BWA                  BorgWarner Inc.
# 499      NYQ    HII  Huntington Ingalls Industries,
# 500      NYQ    FMC                  FMC Corporation
# 501      NMS   QRVO                      Qorvo, Inc.
# 502      NYQ   AMTM           Amentum Holdings, Inc.
#
#                                 Longname                  Sector  \
# 0                             Apple Inc.              Technology
# 1                     NVIDIA Corporation              Technology
# 2                  Microsoft Corporation              Technology
# 3                       Amazon.com, Inc.       Consumer Cyclical
# 4                          Alphabet Inc.  Communication Services
# ..                                   ...                     ...
# 498                      BorgWarner Inc.       Consumer Cyclical
# 499  Huntington Ingalls Industries, Inc.             Industrials
# 500                      FMC Corporation         Basic Materials
# 501                          Qorvo, Inc.              Technology
# 502               Amentum Holdings, Inc.             Industrials
#
#                            Industry  Currentprice      Marketcap  \
# 0              Consumer Electronics        242.84  3670720643072
# 1                    Semiconductors        142.44  3488355713024
# 2         Software - Infrastructure        443.57  3297889746944
# 3                   Internet Retail        227.03  2387220627456
# 4    Internet Content & Information        176.49  2148483465216
# ..                              ...           ...            ...
# 498                      Auto Parts         33.80     7392059904
# 499             Aerospace & Defense        187.95     7354351616
# Atlanta       15
# Chicago       15
# Dallas        11
#               ..
# Milpitas       1
# Eagle          1
# Durham         1
# Minnetonka     1
# Acton          1
# Length: 236, dtype: int64

# %%
data['sp500_companies'].groupby('Industry').size().sort_values(ascending=False)
# Out:
# Industry
# Utilities - Regulated Electric        23
# Specialty Industrial Machinery        16
# Software - Application                15
# Semiconductors                        14
# Software - Infrastructure             14
#                                       ..
# Furnishings, Fixtures & Appliances     1
# Gold                                   1
# Grocery Stores                         1
# Security & Protection Services         1
# REIT - Diversified                     1
# Length: 114, dtype: int64

# %% [markdown]
# # S&P500 Time Series Visualization

# %%
sp_date = pd.to_datetime(data['sp500_index']['Date'])
sp_close = data['sp500_index']['S&P500']

# %%
fig = go.Figure([go.Scatter(x=sp_date,y=sp_close)])
fig.show()
# Out:
# <div>                            <div id="d36cb4d9-e19f-432f-addd-2e576186ea81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d36cb4d9-e19f-432f-addd-2e576186ea81")) {                    Plotly.newPlot(                        "d36cb4d9-e19f-432f-addd-2e576186ea81",                        [{"x":["2014-12-08T00:00:00","2014-12-09T00:00:00","2014-12-10T00:00:00","2014-12-11T00:00:00","2014-12-12T00:00:00","2014-12-15T00:00:00","2014-12-16T00:00:00","2014-12-17T00:00:00","2014-12-18T00:00:00","2014-12-19T00:00:00","2014-12-22T00:00:00","2014-12-23T00:00:00","2014-12-24T00:00:00","2014-12-26T00:00:00","2014-12-29T00:00:00","2014-12-30T00:00:00","2014-12-31T00:00:00","2015-01-02T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-15T00:00:00","2015-06-16T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-19T00:00:00","2015-06-22T00:00:00","2015-06-23T00:00:00","2015-06-24T00:00:00","2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00","2015-07-01T00:00:00","2015-07-02T00:00:00","2015-07-06T00:00:00","2015-07-07T00:00:00","2015-07-08T00:00:00","2015-07-09T00:00:00","2015-07-10T00:00:00","2015-07-13T00:00:00","2015-07-14T00:00:00","2015-07-15T00:00:00","2015-07-16T00:00:00","2015-07-17T00:00:00","2015-07-20T00:00:00","2015-07-21T00:00:00","2015-07-22T00:00:00","2015-07-23T00:00:00","2015-07- ...

# %% [markdown]
# # Stocks

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Splitting tickers into separate data frames to fit the model pipeline

# %%
data_stock = {
    symbol: group.set_index('Date')[['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']]
    for symbol, group in data['sp500_stocks'].groupby('Symbol')
}

print("Symbols amount:", len(list(data_stock.keys())))
# Out:
# Symbols amount: 503

# %% [markdown]
# ## Save

# %%
output_dir = "./preprocess"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
output_file = output_dir + "/sp500_stocks_historical_data.xlsx"

with pd.ExcelWriter(output_file) as writer:
    for symbol, df_symbol in data_stock.items():
        df_symbol.to_excel(writer, sheet_name=symbol)

print(f"Data saved to {output_file}")
# Out:
# Data saved to ./preprocess/sp500_stocks_historical_data.xlsx

# %%
output_file_index = output_dir + "/sp500_index_historical_data.xlsx"
with pd.ExcelWriter(output_file_index) as writer:
    data['sp500_index'].to_excel(writer, sheet_name="SP500_index")

print(f"Data saved to {output_file_index}")
# Out:
# Data saved to ./preprocess/sp500_index_historical_data.xlsx
